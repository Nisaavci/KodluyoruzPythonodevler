# %% [markdown]
# #### Ödev 1
# Kullanıcıdan pi değeri ve yarıçap bilgisi alarak dairenin alanını hesaplayan bir fonksiyon oluşturulur.

# %%
def daire_alani(pi, r):
    alan = pi * (r ** 2)
    print('Yarıçapı {} olan dairenin alanı: {:.2f}'.format(r, alan))

daire_alani(3.14, 5)
# Out:
# Yarıçapı 5 olan dairenin alanı: 78.50

# %% [markdown]
# #### Ödev 2
#
# Faktöriyel adında fonksiyon oluşturulur. Döngü kullanarak parametre olarak girilen sayının faktöriyeli hesaplanır. Format metodunu kullanılarak ekrana yazdırılır.

# %%
def faktoriyel(sayi):
  sonuc = 1
  orijinal = sayi  # Orijinal değeri sakla
  if sayi == 0 or sayi == 1:
    print('{} sayısının faktoriyeli 1'.format(sayi))
  else:
    while sayi > 1:
      sonuc *= sayi
      sayi -= 1
    print('{} sayısının faktoriyeli {}'.format(orijinal, sonuc))

faktoriyel(5)
# Out:
# 5 sayısının faktoriyeli 120

# %% [markdown]
# #### Ödev 3
# Kişinin fonksiyona doğum yılını vererek kaç yaşında olduğunu hesaplayan bir fonksiyon oluşturun.

# %%
def yas_hesaplama(dogum_yili, bugun):
    yas = bugun - dogum_yili
    return yas #print(f"Kişinin yaşı: {yas}")

yas_hesaplama(2004, 2025)
# Out:
# 21

# %% [markdown]
# #### Ödev 4
#
# Doğum yılı ve isim bilgisi verilen fonksiyon kişinin emekli olup olmadığını söylesin.(Kişi 65 yaşında ise emekli olur.) Burada yaş hesabını yukarıdaki örnekteki fonksiyonu kullanarak yapsın.(Yani fonksiyon içinde fonksiyon kullanmanızı istiyorum :)) Kişi 65 yaşında ya da daha fazlaysa "Emekli oldunuz" yanıtını, 65 yaşından küçükse emekliliğine kaç yıl kaldığını da hesaplayarak "(isim) emekliliğine (yıl) kaldı." yanıtını versin.

# %%
def emeklilik_durumu(isim, dogum_yili, bugun):
    yas = yas_hesaplama(dogum_yili, bugun)  # İç fonksiyon çağrısı
    if yas >= 65:
        print(f"{isim}, emekli oldunuz.")
    else:
        kalan_yil = 65 - yas
        print(f"{isim}, emekliliğinize {kalan_yil} yıl kaldı.")
emeklilik_durumu("Ahmet",1965,2025)
# Out:
# Ahmet, emekliliğinize 5 yıl kaldı.
